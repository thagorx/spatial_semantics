# %% [markdown]
# # How to split features
# what we want is to split a given feature into typical chunks for this we need to find out what the typical size of a features is and then split every feature larger than that into chunks.
#
# first we make a sample of the feature and then we sort them size wise into full intiger bins maybe interpolate with a spline and then find the peak of an given function this is our typical size through wich we then can divide all other features of the same type

# %%
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 2*np.pi+np.pi/4, 2*np.pi/8)
y = np.sin(x)
tck = interpolate.splrep(x, y, s=0)
xnew = np.arange(0, 2*np.pi, np.pi/8)
ynew = interpolate.splev(xnew, tck, der=0)

# %%
tck
# Out:
# (array([0.        , 0.        , 0.        , 0.        , 1.57079633,
#         2.35619449, 3.14159265, 3.92699082, 4.71238898, 6.28318531,
#         6.28318531, 6.28318531, 6.28318531]),
#  array([ 3.44265545e-18,  5.54608516e-01,  1.21921009e+00,  7.83113675e-01,
#          2.45205789e-16, -7.83113675e-01, -1.21921009e+00, -5.54608516e-01,
#         -2.44929360e-16,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00]),
#  3)

# %%
plt.plot(x, y, 'x', xnew, ynew)
plt.legend(['Linear', 'Cubic Spline', 'True'])
plt.axis([-0.05, 6.33, -1.05, 1.05])
plt.title('Cubic-spline interpolation')
plt.show()
